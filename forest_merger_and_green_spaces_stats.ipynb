# %%
import pandas as pd
import geopandas as gpd
import os
import numpy as np
import functions as f

# %% [markdown]
# The data collection stage was performed by administrative regions. Now, we want to put together all green spaces in denmark, into one big dataframe.

# %%
df = pd.DataFrame()

for file in os.listdir("./dataset/raw_unprocessed/green_spaces"):
    place = file.split("_")[0]
    type1 = file.split("_")[1]
    type2 = "_".join(file.replace(".parquet", "").replace("_ALL", "").split("_")[2:])

    x = gpd.read_parquet(f"./dataset/raw_unprocessed/green_spaces/{file}")
    # hey Gino, yoou have to reproject the data before calculating the area
    # dont do this. The files in WGS84 projection
    # x.crs = "EPSG:25832"

    # reproject
    x = x.to_crs(f.DENMARK_CRS)
    x.crs = "EPSG:25832"

    x = x.reset_index()

    x["place"] = place
    x["type1"] = type1
    x["type2"] = type2
    x["area_km"] = x[["geometry"]].area/1000000 # square kilometer instead of square meter
    df = pd.concat([df, x], ignore_index=True)

# %% [markdown]
# Make a summary of the green spaces, including the number, the total area (in km2), the average area and the standard deviation.

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
summary = df[["type1", "type2", "area_km"]].groupby(["type1", "type2"]).agg(Number=("type2", "count"), Total=("area_km", "sum"), AVG=("area_km", "mean"), STD=("area_km", "std")).reset_index()

# %%
summary.sort_values("AVG", ascending=False)
# Out:
#        type1              type2  Number       Total      AVG      STD
# 34     water             lagoon      47   582.41141 12.39173 57.13227
# 23   natural              heath    5538   825.83725  0.14912  1.17797
# 4    landuse           farmland  115907 15444.07420  0.13325  0.24781
# 18   natural              beach     934    75.95641  0.08132  0.89633
# 6    landuse             forest  120330  6532.49036  0.05429  0.49867
# 14   leisure           dog_park     311    16.32359  0.05249  0.15416
# 42     water              river     207    10.75130  0.05194  0.10142
# 20   natural          coastline    1579    78.68648  0.04983  0.44226
# 8    landuse         greenfield    1484    68.34794  0.04606  0.16277
# 10   landuse            orchard     929    35.40959  0.03812  0.05723
# 1    landuse         allotments     729    27.39649  0.03758  0.05986
# 31     water              canal      54     1.76112  0.03261  0.11778
# 11   landuse  recreation_ground    2063    64.86923  0.03144  0.34020
# 9    landuse             meadow   58942  1681.44478  0.02853  0.10816
# 16   leisure             marina     283     5.91387  0.02090  0.03172
# 17   leisure               park    5054   104.37105  0.02065  0.16617
# 22   natural          grassland   12492   241.05141  0.01930  0.04395
# 28   natural              water   96963  1770.92163  0.01826  1.68151
# 35     water               lake   23128   422.35191  0.01826  0.38739
# 13   landuse           vineyard      71     1.26836  0.01786  0.03938
# 38     water              oxbow      21     0.34896  0.01662  0.04342
# 29   natural               wood   10309   122.36200  0.01187  0.06846
# 3    landuse           cemetery    1401    15.45691  0.01103  0.02654
# 0    amenity         grave_yard     969     8.80989  0.00909  0.01141
# 12   landuse      village_green     155     1.19449  0.00771  0.02141
# 37     water               moat     111     0.64783  0.00584  0.00884
# 24   natural              scrub   48753   220.80595  0.00453  0.03126
# 21   natural               fell       5     0.01830  0.00366  0.00184
# 7    landuse              grass   32801   117.82745  0.00359  0.01655
# 41     water          reservoir     387     1.23518  0.00319  0.01030
# 39     water               pond    7153    12.40377  0.00173  0.00519
# 30     water              basin    2254     3.71655  0.00165  0.00388
# 2    landuse              basin    3403     3.97770  0.00117  0.00190
# 15   leisure             garden    3465     3.96071  0.00114  0.00567
# 32     water              ditch      11     0.01174  0.00107  0.00174
# 19   natural               cape     325     0.30143  0.00093  0.01135
# 36     water               lock       7     0.00321  0.00046  0.00037
# 33     water          fish_pass      16     0.00436  0.00027  0.00044
# 25   natural          shrubbery     293     0.05454  0.00019  0.00049
# 40     water    reflecting_pool      51     0.00779  0.00015  0.00030
# 5    landuse          flowerbed     476     0.05213  0.00011  0.00078
# 26   natural             spring     285     0.00289  0.00001  0.00011
# 27   natural           tree_row   17097     0.01945  0.00000  0.00014
# 43  waterway              canal     924     0.00000  0.00000  0.00000
# 44  waterway              river    2432     0.00000  0.00000  0.00000
# 45  waterway             stream   37543     0.00000  0.00000  0.00000
# 46  waterway          waterfall      10     0.00000  0.00000  0.00000

# %%
summary.Number.sum()
# Out:
# 617702

# %% [markdown]
# Let's make a reduced version of the dataset, where we keep the type of green space, its geometry and area. We simplify the polygons with 5 meters tolerance, to optimize storage and computations.

# %% [markdown]
# ## Random sample of a polygon to show the effect of simplification

# %%
df[(df.type1 == "leisure") & (df.type2 == "garden")].geometry.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5f4d9d94724ce06873c09c3f86ac431 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5f4d9d94724ce06873c09c3f86ac431&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5f4d9d94724ce06873c09c3f86ac431 = L.map(
#                 &quot;map_a5f4d9d94724ce06873c09c3f86ac431&quot;,
#                 {
#                     center: [56.183366899999996, 11.54598245],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_a5f4d9d94724ce06873c09c3f86ac431);
#
#
#
#
#
#             var tile_layer_cf2f8ffb23816b02f96843e06a9bedc4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_cf2f8ffb23816b02f96843e06a9bedc4.addTo(map_a5f4d9d94724ce06873c09c3f86ac431);
#
#
#             map_a5f4d9d94724ce06873c09c3f86ac431.fitBounds(
#                 [[54.775295599999986, 8.119836100000002], [57.5914382, 14.9721288]],
#                 {}
#             );
#
#
#         function geo_json_6518f2b8591c7cf8055feda0c5542888_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_6518f2b8591c7cf8055feda0c5542888_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_6518f2b8591c7cf8055feda0c5542888_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_6518f2b8591c7cf8055feda0c5542888_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_6518f2b8591c7cf8055feda0c5542888_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_6518f2b8591c7cf8055feda0c5542888.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_6518f2b8591c7cf8055feda0c5542888_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_6518f2b8591c7cf8055feda0c5542888 = L.geoJson(null, {
#                 onEachFeature: geo_json_6518f2b8591c7cf8055feda0c5542888_onEachFeature,
#
#                 style: geo_json_6518f2b8591c7cf8055feda0c5542888_styler,
#                 pointToLayer: geo_json_6518f2b8591c7cf8055feda0c5542888_pointToLayer,
#         });
#
#         function geo_json_6518f2b8591c7cf8055feda0c5542888_add (data) {
#             geo_json_6518f2b8591c7cf8055feda0c5542888
#                 .addData(data);
#         }
#             geo_json_6518f2b8591c7cf8055feda0c5542888_add({&quot;bbox&quot;: [8.119836100000002, 54.775295599999986, 14.9721288, 57.5914382], &quot;features&quot;: [{&quot;bbox&quot;: [14.878027100000004, 55.1200076, 14.878027100000004, 55.1200076], &quot;geometry&quot;: {&quot;coordinates&quot;: [14.878027100000004, 55.1200076], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;8781&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [14.703512499999997, 55.10150910000001, 14.704166000000003, 55.10179140000001], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[14.703564499999999, 55.10179140000001], [14.704166000000003, 55.101781499999994], [14.704162499999997, 55.101664], [14.7041612, 55.1016457], [14.704149999999998, 55.1015534], [14.704099299999998, 55.101551099999995], [14.704101999999997, 55.101511399999985], [14.7040339, 55.10150910000001], [14.704035299999996, 55.10154119999999], [14.703981899999999, 55.10154189999999], [14.703972600000002, 55.101643300000006], [14.703512499999997, 55.101637299999986], [14.703564499999999, 55.10179140000001]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;8782&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [14.703600500000002, 55.10132449999998, 14.703795900000001, 55.1015191], &quot;geometry&quot;: {&quot

# %% [markdown]
# Polygon before simplification

# %%
df[527757:527758].geometry.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24571e1f3125690f4a1803b8002a64d2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24571e1f3125690f4a1803b8002a64d2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_24571e1f3125690f4a1803b8002a64d2 = L.map(
#                 &quot;map_24571e1f3125690f4a1803b8002a64d2&quot;,
#                 {
#                     center: [55.045629749999996, 12.13691325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_24571e1f3125690f4a1803b8002a64d2);
#
#
#
#
#
#             var tile_layer_fedd5599a65a1592e8ef842dd82492a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fedd5599a65a1592e8ef842dd82492a7.addTo(map_24571e1f3125690f4a1803b8002a64d2);
#
#
#             map_24571e1f3125690f4a1803b8002a64d2.fitBounds(
#                 [[55.042907699999994, 12.1292535], [55.0483518, 12.144573]],
#                 {}
#             );
#
#
#         function geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_b120bd33823a0f16fd0fdaf1d135d9a6.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_b120bd33823a0f16fd0fdaf1d135d9a6 = L.geoJson(null, {
#                 onEachFeature: geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_onEachFeature,
#
#                 style: geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_styler,
#                 pointToLayer: geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_pointToLayer,
#         });
#
#         function geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_add (data) {
#             geo_json_b120bd33823a0f16fd0fdaf1d135d9a6
#                 .addData(data);
#         }
#             geo_json_b120bd33823a0f16fd0fdaf1d135d9a6_add({&quot;bbox&quot;: [12.1292535, 55.042907699999994, 12.144573, 55.0483518], &quot;features&quot;: [{&quot;bbox&quot;: [12.1292535, 55.042907699999994, 12.144573, 55.0483518], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.1305303, 55.04719769999999], [12.1292535, 55.04713189999999], [12.129260200000001, 55.047299699999996], [12.1292999, 55.0474335], [12.1297249, 55.0474656], [12.1297692, 55.04759539999999], [12.129275099999997, 55.04803379999999], [12.1294293, 55.0480691], [12.1296492, 55.0480929], [12.1297579, 55.0481214], [12.1298222, 55.04815210000001], [12.1299134, 55.048215899999995], [12.1301334, 55.04830569999998], [12.1302956, 55.04833959999999], [12.130510200000002, 55.0483472], [12.130813300000002, 55.04829500000001], [12.1309796, 55.0482274], [12.1312378, 55.04805429999999], [12.1313149, 55.0480292], [12.131470399999998, 55.0480199], [12.131585799999998, 55.0480184], [12.1318567, 55.04801379999999], [12.132031, 55.048002999999994], [12.1321812, 55.04800300000001], [12.132301900000002, 55.0480292], [12.132538, 55.0481198], [12.1326882, 55.048158199999996], [12.1328625, 55.048168999999994], [12.1332809, 55.048148999999995], [12.1334231, 55.04815519999999], [12.1335183, 55.0481744], [12.1337329, 55.048245800000004], [12.133853599999998, 55.048257299999996], [12.1340199, 55.04825499999999], [12.13456

# %% [markdown]
# Polygon after simplification

# %%
df[527757:527758].geometry.simplify(5).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05bc83caa5c9bbc532f62cb9ffe2aa98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05bc83caa5c9bbc532f62cb9ffe2aa98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05bc83caa5c9bbc532f62cb9ffe2aa98 = L.map(
#                 &quot;map_05bc83caa5c9bbc532f62cb9ffe2aa98&quot;,
#                 {
#                     center: [55.04562745, 12.13691325],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_05bc83caa5c9bbc532f62cb9ffe2aa98);
#
#
#
#
#
#             var tile_layer_a20f40c35e5cb97c8165743650356e48 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a20f40c35e5cb97c8165743650356e48.addTo(map_05bc83caa5c9bbc532f62cb9ffe2aa98);
#
#
#             map_05bc83caa5c9bbc532f62cb9ffe2aa98.fitBounds(
#                 [[55.042907699999994, 12.1292535], [55.048347199999995, 12.144573]],
#                 {}
#             );
#
#
#         function geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87 = L.geoJson(null, {
#                 onEachFeature: geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_onEachFeature,
#
#                 style: geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_styler,
#                 pointToLayer: geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_pointToLayer,
#         });
#
#         function geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_add (data) {
#             geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87
#                 .addData(data);
#         }
#             geo_json_f40b3cc2a5188d0aae6b6147cf2f1b87_add({&quot;bbox&quot;: [12.1292535, 55.042907699999994, 12.144573, 55.048347199999995], &quot;features&quot;: [{&quot;bbox&quot;: [12.1292535, 55.042907699999994, 12.144573, 55.048347199999995], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[12.1305303, 55.04719769999999], [12.1292535, 55.04713189999999], [12.1292999, 55.0474335], [12.1297249, 55.0474656], [12.1297692, 55.04759539999999], [12.129275099999997, 55.04803379999999], [12.1297579, 55.0481214], [12.1302956, 55.04833959999999], [12.130813300000002, 55.04829500000001], [12.1313149, 55.0480292], [12.1321812, 55.04800300000001], [12.1326882, 55.048158199999996], [12.1334231, 55.04815519999999], [12.133853599999998, 55.048257299999996], [12.134756099999999, 55.048207399999995], [12.1357754, 55.048347199999995], [12.136840200000002, 55.048098300000014], [12.139335999999998, 55.0478847], [12.140132599999996, 55.0476911], [12.140895699999998, 55.047731099999986], [12.1412739, 55.04758050000001], [12.1424702, 55.046829], [12.1425077, 55.04668769999999], [12.142214, 55.04642340000001], [12.143247999999998, 55.04632809999999], [12.1438622, 55.0459639], [12.143824699999998, 55.0456504], [12.1441466, 55.045379999999994], [12.1440983, 55.0451571], [12.144447, 55.0449589], [12.144573, 55.0447622], [12.1444496, 55.04432580000001], [12.1440285, 55.0438955], [12.14381130

# %%
reduced = df[["type1", "type2", "geometry", "area_km"]].copy()
reduced.geometry = reduced.simplify(5)

# %%
reduced
# Out:
#           type1       type2  \
# 0       amenity  grave_yard
# 1       amenity  grave_yard
# 2       amenity  grave_yard
# 3       amenity  grave_yard
# 4       amenity  grave_yard
# ...         ...         ...
# 617697    water       river
# 617698    water       river
# 617699    water       river
# 617700    water       river
# 617701    water       river
#
#                                                  geometry  area_km
# 0       POLYGON ((868651.634 6136455.972, 868674.825 6...  0.00440
# 1       POLYGON ((891462.668 6118760.110, 891468.951 6...  0.00368
# 2       POLYGON ((871040.481 6118525.349, 871098.664 6...  0.00702
# 3       POLYGON ((877690.109 6118708.526, 877792.150 6...  0.00760
# 4       POLYGON ((863660.833 6119954.343, 863460.452 6...  0.04445
# ...                                                   ...      ...
# 617697  POLYGON ((665138.055 6183776.697, 665095.266 6...  0.12376
# 617698  POLYGON ((671309.138 6143210.684, 671307.632 6...  0.00381
# 617699  POLYGON ((640169.170 6140546.869, 640188.573 6...  0.02047
# 617700  POLYGON ((640963.105 6140376.982, 640969.944 6...  0.04175
# 617701  POLYGON ((635693.579 6156623.914, 635782.184 6...  0.04230
#
# [617702 rows x 4 columns]

# %% [markdown]
# Save the resulting geodataframe.

# %%
reduced.to_parquet("./dataset/raw_unprocessed/green_spaces2.parquet")

# %%
f.geoseries_to_geopandas(reduced, crs=f.DENMARK_CRS).to_parquet("./dataset/raw_unprocessed/green_spaces.parquet")

# %%
green_areas = gpd.read_parquet("dataset/processed/green_spaces_crossed_by_bikelane_wgs84.parquet")

# %%
a = reduced.loc[green_areas.reset_index(level=[0,1]).level_0].groupby(["type1", "type2"]).agg(Number=("type2", "count"), Total=("area_km", "sum"), AVG=("area_km", "mean"), STD=("area_km", "std")).reset_index()
a = a.sort_values("Number", ascending=False)
a.Number.sum()
# Out:
# 66179

# %%
with open("table.txt", "w") as outfile:

    for ix, row in a.iterrows():
        outfile.write(" & ".join(map(str, row.values)))
        outfile.write("\\\\")
        outfile.write("\n")

# %%
green_areas = gpd.read_parquet("./dataset/raw_unprocessed/green_spaces2.parquet")
green_areas
# Out:
#           type1       type2  \
# 0       amenity  grave_yard
# 1       amenity  grave_yard
# 2       amenity  grave_yard
# 3       amenity  grave_yard
# 4       amenity  grave_yard
# ...         ...         ...
# 617697    water       river
# 617698    water       river
# 617699    water       river
# 617700    water       river
# 617701    water       river
#
#                                                  geometry  area_km
# 0       POLYGON ((868651.634 6136455.972, 868674.825 6...  0.00440
# 1       POLYGON ((891462.668 6118760.110, 891468.951 6...  0.00368
# 2       POLYGON ((871040.481 6118525.349, 871098.664 6...  0.00702
# 3       POLYGON ((877690.109 6118708.526, 877792.150 6...  0.00760
# 4       POLYGON ((863660.833 6119954.343, 863460.452 6...  0.04445
# ...                                                   ...      ...
# 617697  POLYGON ((665138.055 6183776.697, 665095.266 6...  0.12376
# 617698  POLYGON ((671309.138 6143210.684, 671307.632 6...  0.00381
# 617699  POLYGON ((640169.170 6140546.869, 640188.573 6...  0.02047
# 617700  POLYGON ((640963.105 6140376.982, 640969.944 6...  0.04175
# 617701  POLYGON ((635693.579 6156623.914, 635782.184 6...  0.04230
#
# [617702 rows x 4 columns]
